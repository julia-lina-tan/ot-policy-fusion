# %% [markdown]
# <a href="https://colab.research.google.com/github/julia-lina-tan/ot-policy-fusion/blob/main/reacher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro
#
# This notebook trains agents from Stable Baselines3 in the "Reacher" Gym environment.
#
# 1. An agent will be trained to reach for rewards in the 1st quadrant of the workspace
# 2. An agent will be trained to reach for rewards in the 2nd quadrant of the workspace
# 3. A fused agent will be initialised from these two previous agents using OT techniques
# 4. The fused agent will relearn to reach for rewards in both the 1st and 2nd quadrants of the workspace
# 5. The effectiveness of initialising via fusion (as compared to relearning from the original models or creating a new model from scratch) will be evaluated

# %% [markdown]
# # Setup
#
# Install Stable Baselines and other dependencies.

# %%
# !pip install stable-baselines3[extra]
# !apt install swig cmake
# !pip install stable-baselines3[extra] box2d box2d-kengz

# %%
# Additional installations/imports for rendering Gym environment

# !apt-get install -y xvfb x11-utils
# !pip install gym[box2d]==0.17.* pyvirtualdisplay==0.2.* PyOpenGL==3.1.* PyOpenGL-accelerate==3.1.* 
# !apt-get update
# !apt-get install imagemagick

import pyvirtualdisplay
_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
_ = _display.start()

# %% [markdown]
# Install [pybullet-gym](https://github.com/benelot/pybullet-gym) and import Reacher environment.

# %%
# !git clone https://github.com/benelot/pybullet-gym.git
# !cd pybullet-gym && pip install -e .

# %% [markdown]
# Restart local runtime for pybulletgym import to work.

# %%
import gym  # open ai gym
import pybulletgym  # register PyBullet enviroments with open ai gym

env = gym.make('ReacherPyBulletEnv-v0')
env.reset()  # should return a state vector if everything worked

print(env.action_space)
print(env.observation_space)

# %% [markdown]
# ## Configure target location
#
# Configure valid spaces so we can train different agents on different quadrants.
#
# The first agent will only be able to reach targets in the first quadrant only.

# %%
def custom_first_quadrant(robot, __p):

    minX = -0.27
    maxX = 0
    minY = 0
    maxY = 0.27
    
    robot.jdict['target_x'].reset_current_position(
        robot.np_random.uniform(low=minX, high=maxX), 0)
    
    robot.jdict['target_y'].reset_current_position(
        robot.np_random.uniform(low=minY, high=maxY), 0)
    
    robot.fingertip = robot.parts["fingertip"]
    robot.target = robot.parts["target"]
    robot.central_joint = robot.jdict["joint0"]
    robot.elbow_joint = robot.jdict["joint1"]
    robot.central_joint.reset_current_position(robot.np_random.uniform(low=-3.14, high=3.14), 0)
    robot.elbow_joint.reset_current_position(robot.np_random.uniform(low=-3.14, high=3.14), 0)

# %% [markdown]
# Overwrite existing method so that we can configure the target locations.

# %%
import types

def overwrite_method(custom_foo, env):
  env.robot.robot_specific_reset = types.MethodType(custom_foo, env.robot)

overwrite_method(custom_first_quadrant, env)

# %%
env.reset()

# %% [markdown]
# Import RL policy, RL agents and wrappers.

# %%
import os
import numpy as np
import torch as pt
import matplotlib.pyplot as plt

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor

# %% [markdown]
# ## Rendering agent in environment

# %%
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import animation

def env_render(env):
    view_matrix = env.robot._p.computeViewMatrixFromYawPitchRoll(cameraTargetPosition=[0,0,0.05],
                                                      distance=0.7,
                                                      yaw=0,
                                                      pitch=-90,
                                                      roll=0,
                                                      upAxisIndex=2)
    proj_matrix = env.robot._p.computeProjectionMatrixFOV(fov=60,
                                                  aspect=float(960) /720,
                                                  nearVal=0.1,
                                                  farVal=100.0)
    (_, _, px, _, _) = env.robot._p.getCameraImage(width=960,
                                          height=720,
                                          viewMatrix=view_matrix,
                                          projectionMatrix=proj_matrix,
                                          renderer=env.robot._p.ER_BULLET_HARDWARE_OPENGL)

    rgb_array = np.array(px, dtype=np.uint8)
    rgb_array = np.reshape(rgb_array, (720,960, 4))
    rgb_array = rgb_array[:, :, :3]
    return rgb_array

def save_frames_as_gif(frames, path='../content', filename='gym_animation.gif'):

    #Mess with this to change frame size
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi=72)

    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
    anim.save(path + filename, writer='imagemagick', fps=60)

def render_agent_in_env(agent, env, n_eval_episodes=5, path='../content', filename='gym_animation'):
    for i in range(n_eval_episodes):
      frames = []
      obs = env.reset()
      for t in range(500):

          #Render to frames buffer
          frame = env_render(env)
          cv2.putText(frame, text=f'Episode {i+1}', org=(50,50), fontFace=cv2.FONT_HERSHEY_DUPLEX, fontScale=0.8, color=(0,0,0))
          frames.append(frame)
          action, _states = agent.predict(obs)
          obs, rewards, done, info = env.step(action)
          if done:
            break
      save_frames_as_gif(frames, path=path, filename=f'{filename}-ep{i+1}.gif')

# %% [markdown]
# ## Extracting policy from model parameters

# %%
def get_weights(model, net='policy'):
    """
    Get weights of policy/action/value net.

    :param model: (dict) the MLP policy model 
    :param net: (str) policy/action/value
    """
    policy = model.get_parameters()['policy']

    if net == 'policy':
        layer_weights = [policy['mlp_extractor.policy_net.0.weight'], policy['mlp_extractor.policy_net.2.weight']]
    else:
        layer_weights = [policy[f'{net}_net.weight']]

    return [layer.numpy() for layer in layer_weights]

# %% [markdown]
# # Train agent

# %% [markdown]
# Get learning curve from training episodes.

# %%
from stable_baselines3.common.monitor import load_results
from stable_baselines3.common import results_plotter
from stable_baselines3.common.results_plotter import *
X_TIMESTEPS = 'timesteps'
X_EPISODES = 'episodes'
X_WALLTIME = 'walltime_hrs'
POSSIBLE_X_AXES = [X_TIMESTEPS, X_EPISODES, X_WALLTIME]
EPISODES_WINDOW = 100
COLORS = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 'purple', 'pink',
          'brown', 'orange', 'teal', 'coral', 'lightblue', 'lime', 'lavender', 'turquoise',
          'darkgreen', 'tan', 'salmon', 'gold', 'lightpurple', 'darkred', 'darkblue']

def plot_training_curve(dirs, num_timesteps, xaxis, task_name, legend=None):
    """
    plot the results

    :param dirs: ([str]) the save location of the results to plot
    :param num_timesteps: (int or None) only plot the points below this value
    :param xaxis: (str) the axis for the x and y output
        (can be X_TIMESTEPS='timesteps', X_EPISODES='episodes' or X_WALLTIME='walltime_hrs')
    :param task_name: (str) the title of the task to plot
    """

    tslist = []
    for folder in dirs:
        timesteps = load_results(folder)
        if num_timesteps is not None:
            timesteps = timesteps[timesteps.l.cumsum() <= num_timesteps]
        tslist.append(timesteps)
    xy_list = [ts2xy(timesteps_item, xaxis) for timesteps_item in tslist]
    plot_curve(xy_list, xaxis, task_name, legend)

def plot_curve(xy_list, xaxis, title, legend):
    """
    plot the curve

    :param xy_list: ([(np.ndarray, np.ndarray)]) the x and y coordinates to plot
    :param xaxis: (str) the axis for the x and y output
        (can be X_TIMESTEPS='timesteps', X_EPISODES='episodes' or X_WALLTIME='walltime_hrs')
    :param title: (str) the title of the plot
    """

    plt.figure(figsize=(8, 2))
    maxx = max(xy[0][-1] for xy in xy_list)
    minx = 0
    for (i, (x, y)) in enumerate(xy_list):
        color = COLORS[i]
        # plt.plot(x, y)
        # Do not plot the smoothed curve at all if the timeseries is shorter than window size.
        if x.shape[0] >= EPISODES_WINDOW:
            # Compute and plot rolling mean with window of size EPISODE_WINDOW
            x, y_mean = window_func(x, y, EPISODES_WINDOW, np.mean)
            plt.plot(x, y_mean, color=color)
    plt.xlim(minx, maxx)
    plt.title(title)
    plt.xlabel(xaxis)
    plt.ylabel("Episode Rewards")
    if legend is not None:
        plt.legend(legend, bbox_to_anchor=(1.04,1), loc="upper left")

# %%
log_dir = '../content/agent1/results/'
os.makedirs(log_dir, exist_ok=True)

env = Monitor(env, log_dir)

model_one = PPO('MlpPolicy', env, verbose=1, seed=1)
timesteps = 5e5
model_one.learn(total_timesteps=timesteps)

plot_training_curve([log_dir], timesteps, results_plotter.X_TIMESTEPS, "Agent training on targets in quadrant 1")
plt.show()

# %% [markdown]
# ## Get layer weights of policy net

# %%
policy_weights = get_weights(model_one, net='policy')

# %% [markdown]
# Get weights of action net (i.e. actor layer of the policy).

# %%
action_weights = get_weights(model_one, net='action')
policy_weights.append(action_weights[0])

policy_weights_all = [policy_weights]
print([layer.shape for layer in policy_weights])
# Out:
# [(64, 9), (64, 64), (2, 64)]

# %% [markdown]
# # Test agent
#
# Test on separate evaluation environment.

# %%
from stable_baselines3.common.evaluation import evaluate_policy

def plot_rewards(mean_reward, title=None):
    plt.figure(figsize=(10,5))
    plt.title(title)
    plt.xlabel('Episodes')
    plt.ylabel('Rewards at episode')
    plt.xticks(list(range(1, len(mean_reward)+1)))
    plt.plot(list(range(1, len(mean_reward)+1)), mean_reward, marker='o')
    plt.show()

# %%
# Create separate evaluation environment
eval_env = gym.make('ReacherPyBulletEnv-v0')
overwrite_method(custom_first_quadrant, eval_env)
eval_env.reset()

ep_rewards, ep_steps = evaluate_policy(model_one, eval_env, n_eval_episodes=10, deterministic=True, return_episode_rewards=True)

print(f'mean reward={(sum(ep_rewards)/len(ep_rewards)):.2f} +/- {np.std(ep_rewards):.2f}')
plot_rewards(ep_rewards, title='Rewards over evaluation episodes')

# %% [markdown]
# Visualise the performance of the agent over a number of evaluation episodes.

# %%
os.makedirs('../content/agent1/rendering/', exist_ok=True)
render_agent_in_env(model_one, eval_env, n_eval_episodes=5, path='../content/agent1/rendering/', filename='agent1')

# %% [markdown]
# # Create second agent
#
# This agent will be trained to reach targets in the second quadrant only.

# %%
def custom_second_quadrant(robot, __p):

    minX = 0
    maxX = 0.27
    minY = 0
    maxY = 0.27
    
    robot.jdict['target_x'].reset_current_position(
        robot.np_random.uniform(low=minX, high=maxX), 0)
    
    robot.jdict['target_y'].reset_current_position(
        robot.np_random.uniform(low=minY, high=maxY), 0)
    
    robot.fingertip = robot.parts["fingertip"]
    robot.target = robot.parts["target"]
    robot.central_joint = robot.jdict["joint0"]
    robot.elbow_joint = robot.jdict["joint1"]
    robot.central_joint.reset_current_position(robot.np_random.uniform(low=-3.14, high=3.14), 0)
    robot.elbow_joint.reset_current_position(robot.np_random.uniform(low=-3.14, high=3.14), 0)

# %%
env = gym.make('ReacherPyBulletEnv-v0')
overwrite_method(custom_second_quadrant, env)
env.reset()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# array([ 0.25799343,  0.09145609, -0.27650477, -0.21110544, -0.92423738,
#        -0.38181835,  0.        ,  0.63861543,  0.        ])

# %% [markdown]
# Create another agent and train it on the different environment.

# %%
log_dir = '../content/agent2/results/'
os.makedirs(log_dir, exist_ok=True)

env = Monitor(env, log_dir)

model_two = PPO('MlpPolicy', env, verbose=1, seed=1)
timesteps=5e5
model_two.learn(total_timesteps=timesteps)

plot_training_curve([log_dir], timesteps, results_plotter.X_TIMESTEPS, "Agent training on targets in quadrant 2")
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# |    loss                 | 1.43        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00604    |
# |    std                  | 0.914       |
# |    value_loss           | 3.52        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -6.3         |
# | time/                   |              |
# |    fps                  | 553          |
# |    iterations           | 19           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0096339565 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.839        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.739        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0099      |
# |    std                  | 0.901        |
# |    value_loss           | 1.95         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -5.38       |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 20          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006271784 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0064     |
# |    std                  | 0.894       |
# |    value_loss           | 4.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -5.56       |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 21          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012234426 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.891       |
# |    value_loss           | 2.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -5.17       |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 22          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010670628 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.83        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00889    |
# |    std                  | 0.885       |
# |    value_loss           | 6.23        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -5.32        |
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 23           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0068465774 |
# |    clip_fraction        | 0.0845       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.727        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.77         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 0.878        |
# |    value_loss           | 5            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | -3.64        |
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 24           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0072157546 |
# |    clip_fraction        | 0.0811       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.55        |
# |    explained_variance   | 0.827        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.76         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00732     |
# |    std                  | 0.862        |
# |    value_loss           | 4.08         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -3.08       |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 25          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009523137 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.668       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.862       |
# |    value_loss           | 2.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -0.703      |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 26          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011345448 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.68        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00925    |
# |    std                  | 0.84        |
# |    value_loss           | 1.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 0.264       |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 27          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008478546 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00912    |
# |    std                  | 0.831       |
# |    value_loss           | 5.78        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 150       |
# |    ep_rew_mean          | 1.73      |
# | time/                   |           |
# |    fps                  | 556       |
# |    iterations           | 28        |
# |    time_elapsed         | 103       |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.0096028 |
# |    clip_fraction        | 0.0895    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.45     |
# |    explained_variance   | 0.901     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1         |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -0.00614  |
# |    std                  | 0.817     |
# |    value_loss           | 2.15      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 2.71        |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 29          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.007770598 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00819    |
# |    std                  | 0.802       |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 4.29        |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 30          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008472091 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.614       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00978    |
# |    std                  | 0.789       |
# |    value_loss           | 1.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 5.93        |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 31          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008348758 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.616       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00982    |
# |    std                  | 0.792       |
# |    value_loss           | 1.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 7.56        |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 32          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009301133 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.332       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00858    |
# |    std                  | 0.781       |
# |    value_loss           | 1.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 7.47        |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 33          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008603664 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.242       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00805    |
# |    std                  | 0.781       |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 7.86        |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 34          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010861341 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.523       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00761    |
# |    std                  | 0.763       |
# |    value_loss           | 1.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 7.83        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 35          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009524317 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.268       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00522    |
# |    std                  | 0.752       |
# |    value_loss           | 0.668       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 8.44         |
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 36           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0064747822 |
# |    clip_fraction        | 0.07         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.413        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00386     |
# |    std                  | 0.744        |
# |    value_loss           | 0.972        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 8.53         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 37           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0065093217 |
# |    clip_fraction        | 0.0918       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.23        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.416        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00693     |
# |    std                  | 0.739        |
# |    value_loss           | 0.78         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 8.15        |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 38          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009112172 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.448       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00542    |
# |    std                  | 0.738       |
# |    value_loss           | 1.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 7.6         |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 39          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011209277 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.52        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00654    |
# |    std                  | 0.72        |
# |    value_loss           | 1.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 8.51        |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 40          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009140175 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.221       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 0.713       |
# |    value_loss           | 0.521       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 9.45        |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 41          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009325874 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.395       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0074     |
# |    std                  | 0.704       |
# |    value_loss           | 0.957       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 42          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.005667606 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.438       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00256    |
# |    std                  | 0.695       |
# |    value_loss           | 1.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 43          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005844138 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.292       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00382    |
# |    std                  | 0.692       |
# |    value_loss           | 0.685       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 11.7        |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 44          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008482553 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.285       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00645    |
# |    std                  | 0.675       |
# |    value_loss           | 0.726       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 45          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008020924 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.113       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00849    |
# |    std                  | 0.653       |
# |    value_loss           | 0.493       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.8        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 46          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.010240342 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00498    |
# |    std                  | 0.635       |
# |    value_loss           | 0.459       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 47          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011432286 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.613       |
# |    value_loss           | 0.441       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 48          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010492248 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00333    |
# |    std                  | 0.599       |
# |    value_loss           | 0.734       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 12.2         |
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 49           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0058455104 |
# |    clip_fraction        | 0.0732       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.388        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00533     |
# |    std                  | 0.582        |
# |    value_loss           | 0.703        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.2        |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 50          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006467275 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.235       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00346    |
# |    std                  | 0.575       |
# |    value_loss           | 0.529       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 12.2         |
# | time/                   |              |
# |    fps                  | 551          |
# |    iterations           | 51           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0072499933 |
# |    clip_fraction        | 0.0812       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0994       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00486     |
# |    std                  | 0.565        |
# |    value_loss           | 0.427        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 11.9        |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 52          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008871401 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.09        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00567    |
# |    std                  | 0.551       |
# |    value_loss           | 0.457       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 53          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.012250174 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0759      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00882    |
# |    std                  | 0.547       |
# |    value_loss           | 0.343       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 13.1         |
# | time/                   |              |
# |    fps                  | 548          |
# |    iterations           | 54           |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0076341834 |
# |    clip_fraction        | 0.0998       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.122        |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00292     |
# |    std                  | 0.541        |
# |    value_loss           | 0.504        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.5        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 55          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.008589113 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.159       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00374    |
# |    std                  | 0.533       |
# |    value_loss           | 0.525       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.8        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 56          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008965557 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00563    |
# |    std                  | 0.519       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 14.6       |
# | time/                   |            |
# |    fps                  | 546        |
# |    iterations           | 57         |
# |    time_elapsed         | 213        |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.00893488 |
# |    clip_fraction        | 0.0714     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.5       |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.144      |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.00166   |
# |    std                  | 0.513      |
# |    value_loss           | 0.468      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 15.1       |
# | time/                   |            |
# |    fps                  | 546        |
# |    iterations           | 58         |
# |    time_elapsed         | 217        |
# |    total_timesteps      | 118784     |
# | train/                  |            |
# |    approx_kl            | 0.00963244 |
# |    clip_fraction        | 0.0969     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0878     |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0043    |
# |    std                  | 0.513      |
# |    value_loss           | 0.271      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 14          |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 59          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.007944578 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0997      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00697    |
# |    std                  | 0.497       |
# |    value_loss           | 0.344       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 14.1         |
# | time/                   |              |
# |    fps                  | 546          |
# |    iterations           | 60           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0073591247 |
# |    clip_fraction        | 0.0945       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0512       |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00366     |
# |    std                  | 0.487        |
# |    value_loss           | 0.251        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.9        |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 61          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.008417521 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00816    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00461    |
# |    std                  | 0.474       |
# |    value_loss           | 0.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.5        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 62          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.011235461 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0543      |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 0.465       |
# |    value_loss           | 0.168       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 14.1        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 63          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.012765193 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00337    |
# |    std                  | 0.457       |
# |    value_loss           | 0.232       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 64          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.009699317 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0711      |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00566    |
# |    std                  | 0.457       |
# |    value_loss           | 0.16        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 65           |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 133120       |
# | train/                  |              |
# |    approx_kl            | 0.0075136386 |
# |    clip_fraction        | 0.0891       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0328       |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00269     |
# |    std                  | 0.453        |
# |    value_loss           | 0.302        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 14.2        |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 66          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.006966085 |
# |    clip_fraction        | 0.0821      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0613      |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.000593   |
# |    std                  | 0.45        |
# |    value_loss           | 0.191       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 14.4       |
# | time/                   |            |
# |    fps                  | 548        |
# |    iterations           | 67         |
# |    time_elapsed         | 250        |
# |    total_timesteps      | 137216     |
# | train/                  |            |
# |    approx_kl            | 0.00844366 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.111      |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.00688   |
# |    std                  | 0.448      |
# |    value_loss           | 0.181      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 68          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.008115821 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0766      |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00262    |
# |    std                  | 0.442       |
# |    value_loss           | 0.196       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 15.2       |
# | time/                   |            |
# |    fps                  | 548        |
# |    iterations           | 69         |
# |    time_elapsed         | 257        |
# |    total_timesteps      | 141312     |
# | train/                  |            |
# |    approx_kl            | 0.00886338 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0268     |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.00415   |
# |    std                  | 0.439      |
# |    value_loss           | 0.17       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 15          |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 70          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.009942218 |
# ...
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.36        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0309      |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | 0.000109    |
# |    std                  | 0.127       |
# |    value_loss           | 0.0416      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 229         |
# |    time_elapsed         | 832         |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.013930116 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.38        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.014      |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | 0.00311     |
# |    std                  | 0.125       |
# |    value_loss           | 0.026       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 230         |
# |    time_elapsed         | 835         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.015454576 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00441     |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00107    |
# |    std                  | 0.124       |
# |    value_loss           | 0.0212      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 231         |
# |    time_elapsed         | 839         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.021316355 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.41        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00327     |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | 0.00189     |
# |    std                  | 0.124       |
# |    value_loss           | 0.029       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 18.7       |
# | time/                   |            |
# |    fps                  | 563        |
# |    iterations           | 232        |
# |    time_elapsed         | 842        |
# |    total_timesteps      | 475136     |
# | train/                  |            |
# |    approx_kl            | 0.01908337 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.41       |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0625     |
# |    n_updates            | 2310       |
# |    policy_gradient_loss | -0.00351   |
# |    std                  | 0.124      |
# |    value_loss           | 0.0304     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 233         |
# |    time_elapsed         | 846         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.019391436 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.42        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0891      |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | 0.00106     |
# |    std                  | 0.123       |
# |    value_loss           | 0.0364      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 19.5       |
# | time/                   |            |
# |    fps                  | 564        |
# |    iterations           | 234        |
# |    time_elapsed         | 849        |
# |    total_timesteps      | 479232     |
# | train/                  |            |
# |    approx_kl            | 0.02396845 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.43       |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0136     |
# |    n_updates            | 2330       |
# |    policy_gradient_loss | -0.000453  |
# |    std                  | 0.123      |
# |    value_loss           | 0.0497     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 235         |
# |    time_elapsed         | 852         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.016967561 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.43        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | 0.00178     |
# |    std                  | 0.122       |
# |    value_loss           | 0.0236      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 236         |
# |    time_elapsed         | 856         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.018982053 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.45        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0314      |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | 0.000282    |
# |    std                  | 0.12        |
# |    value_loss           | 0.0237      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 237         |
# |    time_elapsed         | 859         |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.021917554 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.45        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00517    |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | 0.00272     |
# |    std                  | 0.122       |
# |    value_loss           | 0.0424      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 19.9       |
# | time/                   |            |
# |    fps                  | 564        |
# |    iterations           | 238        |
# |    time_elapsed         | 863        |
# |    total_timesteps      | 487424     |
# | train/                  |            |
# |    approx_kl            | 0.02499795 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.44       |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00431    |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | 0.000653   |
# |    std                  | 0.121      |
# |    value_loss           | 0.0441     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 20.2        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 239         |
# |    time_elapsed         | 866         |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.023591563 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.46        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | 0.00603     |
# |    std                  | 0.12        |
# |    value_loss           | 0.0467      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 19.5        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 240         |
# |    time_elapsed         | 870         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.018103575 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.45        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0179      |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00168    |
# |    std                  | 0.122       |
# |    value_loss           | 0.0214      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 241         |
# |    time_elapsed         | 874         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.020668378 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.46        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00207    |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.000135   |
# |    std                  | 0.119       |
# |    value_loss           | 0.0329      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 19.9       |
# | time/                   |            |
# |    fps                  | 564        |
# |    iterations           | 242        |
# |    time_elapsed         | 877        |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.02471108 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.47       |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0874     |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | 0.00668    |
# |    std                  | 0.12       |
# |    value_loss           | 0.0537     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 243         |
# |    time_elapsed         | 881         |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.029476698 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.46        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0487      |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | 0.00192     |
# |    std                  | 0.12        |
# |    value_loss           | 0.0358      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 244         |
# |    time_elapsed         | 884         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.012072519 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.47        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0131      |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | 0.00198     |
# |    std                  | 0.119       |
# |    value_loss           | 0.0231      |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 150      |
# |    ep_rew_mean          | 18.8     |
# | time/                   |          |
# |    fps                  | 564      |
# |    iterations           | 245      |
# |    time_elapsed         | 888      |
# |    total_timesteps      | 501760   |
# | train/                  |          |
# |    approx_kl            | 0.031828 |
# |    clip_fraction        | 0.23     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 1.48     |
# |    explained_variance   | 0.997    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0356   |
# |    n_updates            | 2440     |
# |    policy_gradient_loss | 0.00165  |
# |    std                  | 0.119    |
# |    value_loss           | 0.0344   |
# --------------------------------------

# %% [markdown]
# Get layer weights of policy net and action net.

# %%
policy_weights = get_weights(model_two, net='policy')
action_weights = get_weights(model_two, net='action')
policy_weights.append(action_weights[0])

policy_weights_all.append(policy_weights)
print([layer.shape for layer in policy_weights])
# Out:
# [(64, 9), (64, 64), (2, 64)]

# %% [markdown]
# Test second agent on a separate evaluation environment.

# %%
# Create separate evaluation environment
eval_env = gym.make('ReacherPyBulletEnv-v0')
overwrite_method(custom_second_quadrant, eval_env)
eval_env.reset()

ep_rewards, ep_steps = evaluate_policy(model_two, eval_env, n_eval_episodes=10, deterministic=True, return_episode_rewards=True)

print(f'mean reward={(sum(ep_rewards)/len(ep_rewards)):.2f} +/- {np.std(ep_rewards):.2f}')
plot_rewards(ep_rewards, title='Rewards over evaluation episodes')
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.7/dist-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# mean reward=22.75 +/- 8.16

# %% [markdown]
# Visualise the performance of the agent over a number of evaluation episodes.

# %%
os.makedirs('../content/agent2/rendering/', exist_ok=True)
render_agent_in_env(model_two, eval_env, n_eval_episodes=5, path='../content/agent2/rendering/', filename='agent2')

# %% [markdown]
# # Fuse the agents

# %% [markdown]
# ## Align layers using OT
#
# Compute the OT transport map between the weights, then align the matching nodes to each other using this map.

# %%
# Install optimal transport requirements
# !pip install pot
import ot

# %%
def align_nodes(layer_weights_all, stop_layer_k=3):
    
    # Compute layer-wise transport maps
    for i in range(stop_layer_k):

        # Align other nets (source) to first net (target)
        for j in range(1, len(layer_weights_all)):
            Xs = layer_weights_all[j][i]
            Xt = layer_weights_all[0][i]

            # Reorganise source weights according to previous layer alignment
            if i > 0:
              for pos, w in enumerate(Xs):
                Xs[pos] = w[alignment_idx]

            # Compute optimal transport map using EMD, since matching whole nodes
            ot_emd = ot.da.EMDTransport()
            ot_emd.fit(Xs=Xs, Xt=Xt)

            # Get source net aligned to node positions of target net
            aligned_Xs = ot_emd.inverse_transform(Xt=Xt)

            # Replace original with aligned 
            layer_weights_all[j][i] = aligned_Xs

            # Save as previous layer alignment
            alignment_idx = []
            for w in range(Xs.shape[0]):
              idx = np.argwhere(aligned_Xs == Xs[w])[0][0]
              alignment_idx.append(idx)

    return layer_weights_all

aligned_policy_weights_all = align_nodes(policy_weights_all, stop_layer_k=3)

# %% [markdown]
# ## Average weights
# Average layer weights to fuse the aligned neurons.

# %%
def fuse_policy_weights(aligned_policy_weights_all):
    sum_weights = [np.add(aligned_policy_weights_all[0][0], 
                          aligned_policy_weights_all[1][0]), 
                   np.add(aligned_policy_weights_all[0][1], 
                          aligned_policy_weights_all[1][1]),
                   np.add(aligned_policy_weights_all[0][2],
                          aligned_policy_weights_all[1][2])]
    return [layer/2 for layer in sum_weights]

fused_policy_weights = fuse_policy_weights(aligned_policy_weights_all)

# %% [markdown]
# # Evaluate the fused model
#
# We will evaluate the performance of the fused model on a Reacher environment where targets may be placed anywhere in the first or second quadrants.

# %%
def custom_both_quadrants(robot, __p):

    minX = -0.27
    maxX = 0.27
    minY = 0
    maxY = 0.27
    
    robot.jdict['target_x'].reset_current_position(
        robot.np_random.uniform(low=minX, high=maxX), 0)
    
    robot.jdict['target_y'].reset_current_position(
        robot.np_random.uniform(low=minY, high=maxY), 0)
    
    robot.fingertip = robot.parts["fingertip"]
    robot.target = robot.parts["target"]
    robot.central_joint = robot.jdict["joint0"]
    robot.elbow_joint = robot.jdict["joint1"]
    robot.central_joint.reset_current_position(robot.np_random.uniform(low=-3.14, high=3.14), 0)
    robot.elbow_joint.reset_current_position(robot.np_random.uniform(low=-3.14, high=3.14), 0)

# Create separate evaluation environment
eval_env = gym.make('ReacherPyBulletEnv-v0')
overwrite_method(custom_both_quadrants, eval_env)
eval_env.reset()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# array([ 0.26119095,  0.16465833, -0.37743867, -0.21507525, -0.83734092,
#         0.54668106,  0.        ,  0.61637693,  0.        ])

# %%
def replace_policy(model, new_policy, new_actor):

    # Replace policy net with given policy
    policy = model.get_parameters().get('policy')
    policy['mlp_extractor.policy_net.0.weight'] = pt.from_numpy(new_policy[0])
    policy['mlp_extractor.policy_net.2.weight'] = pt.from_numpy(new_policy[1])
    policy['action_net.weight'] = pt.from_numpy(new_actor)
    updated_param = {'policy': policy}

    # Set policy parameter 
    model.set_parameters(updated_param, exact_match=False)
    return model


env = gym.make('ReacherPyBulletEnv-v0')
overwrite_method(custom_both_quadrants, env)
env.reset()

# Make a new model from fused layers
log_dir = '../content/fused/results/'
os.makedirs(log_dir, exist_ok=True)

env = Monitor(env, log_dir)

fused_model = PPO('MlpPolicy', env, verbose=1, seed=1)
new_policy = fused_policy_weights[:-1]
new_actor = fused_policy_weights[-1]
fused_model = replace_policy(fused_model, new_policy, new_actor)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ## Without retraining

# %%
ep_rewards, ep_steps = evaluate_policy(fused_model, eval_env, n_eval_episodes=10, deterministic=True, return_episode_rewards=True)

print(f'mean reward={(sum(ep_rewards)/len(ep_rewards)):.2f} +/- {np.std(ep_rewards):.2f}')
plot_rewards(ep_rewards, title='Rewards over evaluation episodes')
# Out:
# /usr/local/lib/python3.7/dist-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# mean reward=10.33 +/- 12.38

# %%
os.makedirs('../content/fused/rendering/', exist_ok=True)
render_agent_in_env(fused_model, eval_env, n_eval_episodes=5, path='../content/fused/rendering/', filename='untrained')

# %% [markdown]
# ## With retraining

# %% [markdown]
# Retrain fused model to optimise weights.

# %%
timesteps = 5e5
fused_model.learn(total_timesteps=timesteps)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    loss                 | 4.01        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.785       |
# |    value_loss           | 5.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 5.97        |
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 19          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006884524 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00469    |
# |    std                  | 0.786       |
# |    value_loss           | 3.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 6.69        |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 20          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008706537 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.96        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00581    |
# |    std                  | 0.778       |
# |    value_loss           | 6.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 6.24        |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 21          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009858673 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.971       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00626    |
# |    std                  | 0.773       |
# |    value_loss           | 4.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 6.77        |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 22          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007452384 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.69        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00781    |
# |    std                  | 0.77        |
# |    value_loss           | 4.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 7.17        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 23          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006361923 |
# |    clip_fraction        | 0.0856      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00543    |
# |    std                  | 0.758       |
# |    value_loss           | 2.81        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 7.66         |
# | time/                   |              |
# |    fps                  | 545          |
# |    iterations           | 24           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0047876667 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.7          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00485     |
# |    std                  | 0.748        |
# |    value_loss           | 2.45         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 7.82        |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 25          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008435449 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.858       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00961    |
# |    std                  | 0.742       |
# |    value_loss           | 3.11        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 8.12       |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 26         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00601051 |
# |    clip_fraction        | 0.0982     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.23      |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.582      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.00701   |
# |    std                  | 0.737      |
# |    value_loss           | 2.21       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 8.49        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 27          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007675551 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.713       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0053     |
# |    std                  | 0.727       |
# |    value_loss           | 2.42        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 7.69         |
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 28           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0069443197 |
# |    clip_fraction        | 0.0705       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.893        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.818        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00667     |
# |    std                  | 0.717        |
# |    value_loss           | 2.09         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 8.08        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 29          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008695964 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.811       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00746    |
# |    std                  | 0.711       |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 8.3         |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 30          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008715158 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.584       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.694       |
# |    value_loss           | 1.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 9.01        |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 31          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007010187 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.758       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00621    |
# |    std                  | 0.692       |
# |    value_loss           | 1.66        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 10         |
# | time/                   |            |
# |    fps                  | 544        |
# |    iterations           | 32         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01118617 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.08      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.614      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00895   |
# |    std                  | 0.68       |
# |    value_loss           | 1.49       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 33           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0049882503 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.05        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.254        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00351     |
# |    std                  | 0.671        |
# |    value_loss           | 1.35         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 9.92        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 34          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010985697 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.407       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00705    |
# |    std                  | 0.661       |
# |    value_loss           | 1.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 10.3        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 35          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008192879 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.266       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00651    |
# |    std                  | 0.646       |
# |    value_loss           | 0.838       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 11          |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 36          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009173011 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.312       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00522    |
# |    std                  | 0.643       |
# |    value_loss           | 0.722       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 10.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 37          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007370592 |
# |    clip_fraction        | 0.0684      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00646    |
# |    std                  | 0.635       |
# |    value_loss           | 0.643       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 38          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011520534 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.303       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00619    |
# |    std                  | 0.631       |
# |    value_loss           | 0.785       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 9.67         |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 39           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0097476235 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.745        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00967     |
# |    std                  | 0.622        |
# |    value_loss           | 1.36         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 40          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008555183 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.234       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00714    |
# |    std                  | 0.615       |
# |    value_loss           | 0.551       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 10.6        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 41          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006857156 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.266       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00601    |
# |    std                  | 0.607       |
# |    value_loss           | 0.575       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 11.6        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 42          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009881122 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.291       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0082     |
# |    std                  | 0.605       |
# |    value_loss           | 0.855       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 43          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010221622 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.157       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00681    |
# |    std                  | 0.592       |
# |    value_loss           | 0.598       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 44          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010286585 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.206       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0082     |
# |    std                  | 0.58        |
# |    value_loss           | 0.541       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13          |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 45          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011144982 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00623    |
# |    std                  | 0.573       |
# |    value_loss           | 0.372       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 46          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009969432 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.164       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00487    |
# |    std                  | 0.559       |
# |    value_loss           | 0.411       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13          |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 47          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.012668429 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0953      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0095     |
# |    std                  | 0.558       |
# |    value_loss           | 0.517       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 48          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008785363 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.181       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00595    |
# |    std                  | 0.549       |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.5        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 49          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.012624072 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00932    |
# |    std                  | 0.536       |
# |    value_loss           | 0.346       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 12.7         |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 50           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0063991463 |
# |    clip_fraction        | 0.084        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.57        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0726       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00623     |
# |    std                  | 0.528        |
# |    value_loss           | 0.29         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 51          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.009059763 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00509    |
# |    std                  | 0.52        |
# |    value_loss           | 0.437       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 52          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009617895 |
# |    clip_fraction        | 0.0921      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.113       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00464    |
# |    std                  | 0.511       |
# |    value_loss           | 0.345       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 53          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.015502179 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00329    |
# |    std                  | 0.504       |
# |    value_loss           | 0.428       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.7        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 54          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.007910247 |
# |    clip_fraction        | 0.0761      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.237       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00571    |
# |    std                  | 0.505       |
# |    value_loss           | 0.587       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 14.3        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 55          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.010733488 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0883      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00797    |
# |    std                  | 0.5         |
# |    value_loss           | 0.347       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 14.5        |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 56          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.009466419 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0826      |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00251    |
# |    std                  | 0.495       |
# |    value_loss           | 0.256       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 150          |
# |    ep_rew_mean          | 15.2         |
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 57           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0119977845 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0663       |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00669     |
# |    std                  | 0.491        |
# |    value_loss           | 0.234        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 15.2        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 58          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.012191426 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0486      |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00728    |
# |    std                  | 0.487       |
# |    value_loss           | 0.325       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 59          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.008012063 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.13        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00683    |
# |    std                  | 0.478       |
# |    value_loss           | 0.402       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 15          |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 60          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.010985909 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0568      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00698    |
# |    std                  | 0.472       |
# |    value_loss           | 0.178       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 14.6        |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 61          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.012616763 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0321      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00844    |
# |    std                  | 0.461       |
# |    value_loss           | 0.265       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 14          |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 62          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.011559175 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00359    |
# |    std                  | 0.452       |
# |    value_loss           | 0.221       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.9        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 63          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.011316136 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0598      |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00664    |
# |    std                  | 0.449       |
# |    value_loss           | 0.286       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 64          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.010551546 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.021       |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00669    |
# |    std                  | 0.449       |
# |    value_loss           | 0.237       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 65          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.009451541 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0537      |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.00954    |
# |    std                  | 0.448       |
# |    value_loss           | 0.422       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.7        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 66          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.010574072 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0446      |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.00738    |
# |    std                  | 0.445       |
# |    value_loss           | 0.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 67          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 137216      |
# | train/                  |             |
# |    approx_kl            | 0.010084523 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0583      |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00794    |
# |    std                  | 0.432       |
# |    value_loss           | 0.221       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 13.8        |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 68          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.011482267 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.141       |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00581    |
# |    std                  | 0.425       |
# |    value_loss           | 0.262       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 14.1       |
# | time/                   |            |
# |    fps                  | 543        |
# |    iterations           | 69         |
# |    time_elapsed         | 259        |
# |    total_timesteps      | 141312     |
# | train/                  |            |
# |    approx_kl            | 0.01486188 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0634     |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.00862   |
# |    std                  | 0.418      |
# |    value_loss           | 0.148      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 14.4        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 70          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.010562109 |
# |    clip_fraction        | 0.11        |
# ...
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1           |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0548      |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.00919    |
# |    std                  | 0.148       |
# |    value_loss           | 0.0446      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 17.2       |
# | time/                   |            |
# |    fps                  | 552        |
# |    iterations           | 229        |
# |    time_elapsed         | 848        |
# |    total_timesteps      | 468992     |
# | train/                  |            |
# |    approx_kl            | 0.02504178 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.04       |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0179     |
# |    n_updates            | 2280       |
# |    policy_gradient_loss | 0.00447    |
# |    std                  | 0.145      |
# |    value_loss           | 0.0665     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 230         |
# |    time_elapsed         | 852         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.019969143 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.05        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0194      |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.000746   |
# |    std                  | 0.145       |
# |    value_loss           | 0.0363      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 17.1       |
# | time/                   |            |
# |    fps                  | 552        |
# |    iterations           | 231        |
# |    time_elapsed         | 855        |
# |    total_timesteps      | 473088     |
# | train/                  |            |
# |    approx_kl            | 0.02814927 |
# |    clip_fraction        | 0.191      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.03       |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0108     |
# |    n_updates            | 2300       |
# |    policy_gradient_loss | 0.000858   |
# |    std                  | 0.148      |
# |    value_loss           | 0.0981     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 17         |
# | time/                   |            |
# |    fps                  | 552        |
# |    iterations           | 232        |
# |    time_elapsed         | 859        |
# |    total_timesteps      | 475136     |
# | train/                  |            |
# |    approx_kl            | 0.02299942 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.02       |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00155   |
# |    n_updates            | 2310       |
# |    policy_gradient_loss | -0.00375   |
# |    std                  | 0.147      |
# |    value_loss           | 0.0624     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 233         |
# |    time_elapsed         | 862         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.018120838 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.04        |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.131       |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.00107    |
# |    std                  | 0.146       |
# |    value_loss           | 0.0675      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 234         |
# |    time_elapsed         | 866         |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.020339036 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.04        |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00761     |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.0043     |
# |    std                  | 0.146       |
# |    value_loss           | 0.092       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 235         |
# |    time_elapsed         | 869         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.020919435 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.02        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0288     |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00258    |
# |    std                  | 0.147       |
# |    value_loss           | 0.0379      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 236         |
# |    time_elapsed         | 873         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.023130924 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.05        |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00721     |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | 0.00127     |
# |    std                  | 0.144       |
# |    value_loss           | 0.0517      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 237         |
# |    time_elapsed         | 876         |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.039817676 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.06        |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.016       |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | 0.00928     |
# |    std                  | 0.145       |
# |    value_loss           | 0.0868      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 18.1       |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 238        |
# |    time_elapsed         | 880        |
# |    total_timesteps      | 487424     |
# | train/                  |            |
# |    approx_kl            | 0.01687614 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.06       |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00136   |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.00599   |
# |    std                  | 0.143      |
# |    value_loss           | 0.0381     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 18.8       |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 239        |
# |    time_elapsed         | 883        |
# |    total_timesteps      | 489472     |
# | train/                  |            |
# |    approx_kl            | 0.01880794 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.07       |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00206   |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.00645   |
# |    std                  | 0.144      |
# |    value_loss           | 0.107      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 240         |
# |    time_elapsed         | 887         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.013649527 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.08        |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00491     |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.000903   |
# |    std                  | 0.142       |
# |    value_loss           | 0.0337      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 241         |
# |    time_elapsed         | 891         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.026188435 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.11        |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00325    |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.00783    |
# |    std                  | 0.141       |
# |    value_loss           | 0.0683      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 18.4       |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 242        |
# |    time_elapsed         | 894        |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.02546441 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.13       |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0222     |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.0031    |
# |    std                  | 0.139      |
# |    value_loss           | 0.0739     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 18.5       |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 243        |
# |    time_elapsed         | 898        |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.02399056 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.15       |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0694     |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.00559   |
# |    std                  | 0.137      |
# |    value_loss           | 0.0609     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 244         |
# |    time_elapsed         | 902         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.025462635 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.17        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00654    |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00275    |
# |    std                  | 0.137       |
# |    value_loss           | 0.0466      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 18          |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 245         |
# |    time_elapsed         | 906         |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.020108286 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.18        |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0319      |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00414    |
# |    std                  | 0.136       |
# |    value_loss           | 0.0427      |
# -----------------------------------------

# %% [markdown]
# Compare to training model from scratch.

# %%
env = gym.make('ReacherPyBulletEnv-v0')
overwrite_method(custom_both_quadrants, env)
env.reset()

log_dir = '../content/new-agent/results/'
os.makedirs(log_dir, exist_ok=True)

env = Monitor(env, log_dir)

new_model = PPO('MlpPolicy', env, verbose=1, seed=1)
timesteps=5e5
new_model.learn(total_timesteps=timesteps)

# %% [markdown]
# Compare to retraining original models.

# %%
env = gym.make('ReacherPyBulletEnv-v0')
overwrite_method(custom_both_quadrants, env)
env.reset()

log_dir = '../content/agent1/retraining/results/'
os.makedirs(log_dir, exist_ok=True)

env = Monitor(env, log_dir)

model_one.set_env(env)
timesteps = 5e5
model_one.learn(total_timesteps=timesteps)

# %%
env = gym.make('ReacherPyBulletEnv-v0')
overwrite_method(custom_both_quadrants, env)
env.reset()

log_dir = '../content/agent2/retraining/results/'
os.makedirs(log_dir, exist_ok=True)

env = Monitor(env, log_dir)

model_two.set_env(env)
timesteps = 5e5
model_two.learn(total_timesteps=timesteps)

# %% [markdown]
# Plot all training curves on the same axes.

# %%
all_dirs = ['../content/new-agent/results/', '../content/fused/results/', '../content/agent1/retraining/results/', '../content/agent2/retraining/results']
legend = ['new agent', 'fused agent', 'original quad1 agent', 'original quad2 agent']
plot_training_curve(all_dirs, timesteps, results_plotter.X_TIMESTEPS, "Agents retraining on targets in quadrant 1 and 2", legend=legend)

# %% [markdown]
# ## Evaluation and rendering

# %% [markdown]
# Fused model:

# %%
ep_rewards, ep_steps = evaluate_policy(fused_model, eval_env, n_eval_episodes=10, deterministic=True, return_episode_rewards=True)

print(f'mean reward={(sum(ep_rewards)/len(ep_rewards)):.2f} +/- {np.std(ep_rewards):.2f}')
plot_rewards(ep_rewards, title='Rewards over evaluation episodes')
# Out:
# /usr/local/lib/python3.7/dist-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# mean reward=15.09 +/- 8.08

# %%
os.makedirs('../content/fused/rendering/', exist_ok=True)
render_agent_in_env(fused_model, eval_env, n_eval_episodes=5, path='../content/fused/rendering/', filename='retrained')

# %% [markdown]
# New model:

# %%
ep_rewards, ep_steps = evaluate_policy(new_model, eval_env, n_eval_episodes=10, deterministic=True, return_episode_rewards=True)

print(f'mean reward={(sum(ep_rewards)/len(ep_rewards)):.2f} +/- {np.std(ep_rewards):.2f}')
plot_rewards(ep_rewards, title='Rewards over evaluation episodes')

# %%
os.makedirs('../content/new-agent/rendering/', exist_ok=True)
render_agent_in_env(new_model, eval_env, n_eval_episodes=5, path='../content/new-agent/rendering/', filename='new-agent')

# %% [markdown]
# Retrained agent 1:

# %%
ep_rewards, ep_steps = evaluate_policy(model_one, eval_env, n_eval_episodes=10, deterministic=True, return_episode_rewards=True)

print(f'mean reward={(sum(ep_rewards)/len(ep_rewards)):.2f} +/- {np.std(ep_rewards):.2f}')
plot_rewards(ep_rewards, title='Rewards over evaluation episodes')

# %%
os.makedirs('../content/agent1/retraining/rendering/', exist_ok=True)
render_agent_in_env(model_one, eval_env, n_eval_episodes=5, path='../content/agent1/retraining/rendering/', filename='agent1-retrained')

# %% [markdown]
# Retrained agent 2:

# %%
ep_rewards, ep_steps = evaluate_policy(model_two, eval_env, n_eval_episodes=10, deterministic=True, return_episode_rewards=True)

print(f'mean reward={(sum(ep_rewards)/len(ep_rewards)):.2f} +/- {np.std(ep_rewards):.2f}')
plot_rewards(ep_rewards, title='Rewards over evaluation episodes')

# %%
os.makedirs('../content/agent2/retraining/rendering/', exist_ok=True)
render_agent_in_env(model_two, eval_env, n_eval_episodes=5, path='../content/agent2/retraining/rendering/', filename='agent2-retrained')
